# %% [markdown]
# # Testing different conditions for regression

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from re import sub
from decimal import Decimal
from matplotlib import pyplot as plt
import datetime
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk import word_tokenize, WordNetLemmatizer
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import Imputer, StandardScaler
from sklearn.decomposition import PCA
from math import sqrt
import tests as t
import re
import nltk
from sklearn.preprocessing import OneHotEncoder
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.linear_model import SGDRegressor
import folium
from sklearn.pipeline import Pipeline
from sklearn import linear_model

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import xgboost as xgb
pd.set_option('display.max_columns', 106)
from sklearn.metrics import mean_squared_error, mean_absolute_error

import collections
from sklearn import metrics
from sklearn import datasets
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from collections import Counter
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from collections import Counter
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sousa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sousa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sousa\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
porto = pd.read_csv(r"C:\Users\sousa\Desktop\github\Airbnb Tale of 2 cities\Data Portugal\porto_listings.csv")
lisbon = pd.read_csv(r"C:\Users\sousa\Desktop\github\Airbnb Tale of 2 cities\Data Portugal\lisbon_listings.csv")

# %%
porto.describe()
# Out:
#          Unnamed: 0            id      transit       host_id  \
# count   7662.000000  7.662000e+03  7662.000000  7.662000e+03
# mean    5575.510180  2.245138e+07     0.704124  1.063000e+08
# std     3180.091341  1.010119e+07     0.456465  8.646335e+07
# min        0.000000  4.133900e+04     0.000000  1.544150e+05
# 25%     2910.500000  1.599960e+07     0.000000  2.849896e+07
# 50%     5562.500000  2.318223e+07     1.000000  9.078163e+07
# 75%     8246.750000  3.064100e+07     1.000000  1.730722e+08
# max    11600.000000  4.022729e+07     1.000000  3.103945e+08
#
#        host_response_time  host_response_rate  host_is_superhost  \
# count         7662.000000         7662.000000        7662.000000
# mean             3.816758           97.244845           0.417384
# std              0.521153            9.935759           0.493160
# min              1.000000            0.000000           0.000000
# 25%              4.000000          100.000000           0.000000
# 50%              4.000000          100.000000           0.000000
# 75%              4.000000          100.000000           1.000000
# max              4.000000          100.000000           1.000000
#
#        host_listings_count  host_has_profile_pic  host_identity_verified  \
# count          7662.000000           7662.000000             7662.000000
# mean             14.061864              0.999086                0.283346
# std              46.806267              0.030214                0.450653
# min               0.000000              0.000000                0.000000
# 25%               1.000000              1.000000                0.000000
# 50%               3.000000              1.000000                0.000000
# 75%               8.000000              1.000000                1.000000
# max             505.000000              1.000000                1.000000
#
#           latitude    longitude  is_location_exact    room_type  accommodates  \
# count  7662.000000  7662.000000        7662.000000  7662.000000   7662.000000
# mean     41.153015    -8.616174           0.721091     1.190420      4.061603
# std       0.051021     0.044085           0.448492     0.475091      2.155637
# min      40.807620    -8.783350           0.000000     1.000000      1.000000
# 25%      41.144300    -8.620017           0.000000     1.000000      2.000000
# 50%      41.149820    -8.611820           1.000000     1.000000      4.000000
# 75%      41.157150    -8.604873           1.000000     1.000000      5.000000
# max      41.437220    -8.152620           1.000000     4.000000     18.000000
#
#          bathrooms     bedrooms         beds        price  security_deposit  \
# count  7662.000000  7662.000000  7662.000000  7662.000000       7662.000000
# mean      1.339011     1.465414     2.327591    68.742756          0.901201
# std       0.700539     1.050502     1.668670    45.557227          0.298412
# min       0.000000     0.000000     0.000000     9.000000          0.000000
# 25%       1.000000     1.000000     1.000000    44.000000          1.000000
# 50%       1.000000     1.000000     2.000000    60.000000          1.000000
# 75%       1.500000     2.000000     3.000000    80.000000          1.000000
# max      10.000000    10.000000    18.000000   630.000000          1.000000
#
#        cleaning_fee  guests_included  extra_people  minimum_nights  \
# count   7662.000000      7662.000000   7662.000000     7662.000000
# mean      20.073349         2.174367      9.198512        2.204255
# std       16.645057         1.473742      9.039436        4.516967
# min        0.000000         1.000000      0.000000        1.000000
# 25%       10.000000         1.000000      0.000000        2.000000
# 50%       20.000000         2.000000     10.000000        2.000000
# 75%       25.000000         2.000000     15.000000        2.000000
# max      250.000000        16.000000    200.000000      300.000000
#
#        maximum_nights  has_availability  availability_365  number_of_reviews  \
# count     7662.000000            7662.0       7662.000000        7662.000000
# mean       751.420256               1.0        252.888932          53.805403
# std        497.353990               0.0        116.868910          69.534102
# min          1.000000               1.0          0.000000           1.000000
# 25%         90.000000               1.0        169.000000           9.000000
# 50%       1125.000000               1.0        307.000000          28.000000
# 75%       1125.000000               1.0        348.000000          71.000000
# max       1125.000000               1.0        365.000000         603.000000
#
#        number_of_reviews_ltm  review_scores_rating  review_scores_accuracy  \
# count            7662.000000           7662.000000             7662.000000
# mean               21.261420             93.675020                9.686896
# std                21.219883              6.934821                0.667545
# min                 0.000000             20.000000                2.000000
# 25%                 4.000000             91.000000                9.000000
# 50%                14.000000             95.000000               10.000000
# 75%                33.000000             98.000000               10.000000
# max               173.000000            100.000000               10.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                7662.000000            7662.000000
# mean                    9.565127               9.723440
# std                     0.749973               0.634163
# min                     2.000000               2.000000
# 25%                     9.000000              10.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                  7662.000000             7662.000000
# mean                      9.716262                9.560559
# std                       0.677568                0.662593
# min                       2.000000                2.000000
# 25%                      10.000000                9.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  instant_bookable  is_business_travel_ready  \
# count          7662.000000       7662.000000                    7662.0
# mean              9.380057          0.852780                       0.0
# std               0.768563          0.354348                       0.0
# min               2.000000          0.000000                       0.0
# 25%               9.000000          1.000000                       0.0
# 50%               9.000000          1.000000                       0.0
# 75%              10.000000          1.000000                       0.0
# max              10.000000          1.000000                       0.0
#
#        cancellation_policy  require_guest_profile_picture  \
# count          7662.000000                    7662.000000
# mean              2.234273                       0.007439
# std               0.709685                       0.085936
# min               1.000000                       0.000000
# 25%               2.000000                       0.000000
# 50%               2.000000                       0.000000
# 75%               3.000000                       0.000000
# max               5.000000                       1.000000
#
#        require_guest_phone_verification  calculated_host_listings_count  \
# count                       7662.000000                     7662.000000
# mean                           0.020621                        8.964239
# std                            0.142122                       15.510451
# min                            0.000000                        1.000000
# 25%                            0.000000                        1.000000
# 50%                            0.000000                        3.000000
# 75%                            0.000000                        8.000000
# max                            1.000000                       87.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  7662.000000
# mean                                      7.545810
# std                                      14.732313
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       2.000000
# 75%                                       6.000000
# max                                      87.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   7662.000000
# mean                                       0.894936
# std                                        2.883602
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       29.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# count                                  7662.000000        7662.000000
# mean                                      0.045941           2.246171
# std                                       0.498245           1.871584
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.700000
# 50%                                       0.000000           1.770000
# 75%                                       0.000000           3.400000
# max                                       9.000000          14.310000
#
#        host_name_present  last_review_present  first_review_present  \
# count             7662.0               7662.0                7662.0
# mean                 1.0                  1.0                   1.0
# std                  0.0                  0.0                   0.0
# min                  1.0                  1.0                   1.0
# 25%                  1.0                  1.0                   1.0
# 50%                  1.0                  1.0                   1.0
# 75%                  1.0                  1.0                   1.0
# max                  1.0                  1.0                   1.0
#
#        host_since_present  reviews_p_month_present  amenities_count  \
# count              7662.0                   7662.0      7662.000000
# mean                  1.0                      1.0        27.892195
# std                   0.0                      0.0        11.947580
# min                   1.0                      1.0         1.000000
# 25%                   1.0                      1.0        18.000000
# 50%                   1.0                      1.0        27.000000
# 75%                   1.0                      1.0        35.000000
# max                   1.0                      1.0        93.000000
#
#        neighbourhood_group_cleansed_ESPINHO  ...  \
# count                           7662.000000  ...
# mean                               0.007309  ...
# std                                0.085184  ...
# min                                0.000000  ...
# 25%                                0.000000  ...
# 50%                                0.000000  ...
# 75%                                0.000000  ...
# max                                1.000000  ...
#
#        neighbourhood_cleansed_São João da Madeira  \
# count                                 7662.000000
# mean                                     0.000522
# std                                      0.022844
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      1.000000
#
#        neighbourhood_cleansed_São João de Ver  \
# count                                  7662.0
# mean                                      0.0
# std                                       0.0
# min                                       0.0
# 25%                                       0.0
# 50%                                       0.0
# 75%                                       0.0
# max                                       0.0
#
#        neighbourhood_cleansed_São Mamede de Infesta e Senhora da Hora  \
# count                                        7662.000000
# mean                                            0.007831
# std                                             0.088151
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        neighbourhood_cleansed_São Pedro Fins  \
# count                            7662.000000
# mean                                0.000131
# std                                 0.011424
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        neighbourhood_cleansed_São Pedro de Castelões  \
# count                                    7662.000000
# mean                                        0.000392
# std                                         0.019785
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        neighbourhood_cleansed_Tropeço  neighbourhood_cleansed_Urrô  \
# count                     7662.000000                  7662.000000
# mean                         0.000261                     0.000783
# std                          0.016155                     0.027975
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.000000                     0.000000
# 75%                          0.000000                     0.000000
# max                          1.000000                     1.000000
#
#        neighbourhood_cleansed_Valongo  neighbourhood_cleansed_Vila Chã  \
# count                     7662.000000                      7662.000000
# mean                         0.001305                         0.002610
# std                          0.036106                         0.051028
# min                          0.000000                         0.000000
# 25%                          0.000000                         0.000000
# 50%                          0.000000                         0.000000
# 75%                          0.000000                         0.000000
# max                          1.000000                         1.000000
#
#        neighbourhood_cleansed_Vila Nova da Telha  \
# count                                7662.000000
# mean                                    0.000392
# std                                     0.019785
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        neighbourhood_cleansed_Vila do Conde  \
# count                            7662.00000
# mean                                0.00757
# std                                 0.08668
# min                                 0.00000
# 25%                                 0.00000
# 50%                                 0.00000
# 75%                                 0.00000
# max                                 1.00000
#
#        neighbourhood_cleansed_Vilar de Andorinho  \
# count                                7662.000000
# mean                                    0.001436
# std                                     0.037865
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000
#
#        neighbourhood_cleansed_Vilar de Pinheiro  \
# count                               7662.000000
# mean                                   0.000261
# std                                    0.016155
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    1.000000
#
#        neighbourhood_cleansed_Vilar e Mosteiró  \
# count                              7662.000000
# mean                                  0.000131
# std                                   0.011424
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   1.000000
#
#        neighbourhood_cleansed_Água Longa  neighbourhood_cleansed_Águas Santas  \
# count                        7662.000000                          7662.000000
# mean                            0.000131                             0.000653
# std                             0.011424                             0.025539
# min                             0.000000                             0.000000
# 25%                             0.000000                             0.000000
# 50%                             0.000000                             0.000000
# 75%                             0.000000                             0.000000
# max                             1.000000                             1.000000
#
#        neighbourhood_cleansed_Árvore  bed_type_Futon  bed_type_Pull-out Sofa  \
# count                    7662.000000     7662.000000             7662.000000
# mean                        0.001436        0.000261                0.004960
# std                         0.037865        0.016155                0.070254
# min                         0.000000        0.000000                0.000000
# 25%                         0.000000        0.000000                0.000000
# 50%                         0.000000        0.000000                0.000000
# 75%                         0.000000        0.000000                0.000000
# max                         1.000000        1.000000                1.000000
#
#        bed_type_Real Bed  property_type_Barn  property_type_Bed and breakfast  \
# count        7662.000000         7662.000000                      7662.000000
# mean            0.994649            0.000131                         0.003524
# std             0.072960            0.011424                         0.059261
# min             0.000000            0.000000                         0.000000
# 25%             1.000000            0.000000                         0.000000
# 50%             1.000000            0.000000                         0.000000
# 75%             1.000000            0.000000                         0.000000
# max             1.000000            1.000000                         1.000000
#
#        property_type_Boat  property_type_Boutique hotel  \
# count         7662.000000                   7662.000000
# mean             0.004437                      0.002871
# std              0.066471                      0.053511
# min              0.000000                      0.000000
# 25%              0.000000                      0.000000
# 50%              0.000000                      0.000000
# 75%              0.000000                      0.000000
# max              1.000000                      1.000000
#
#        property_type_Bungalow  property_type_Cabin  property_type_Camper/RV  \
# count             7662.000000          7662.000000              7662.000000
# mean                 0.001175             0.000261                 0.002219
# std                  0.034255             0.016155                 0.047054
# min                  0.000000             0.000000                 0.000000
# 25%                  0.000000             0.000000                 0.000000
# 50%                  0.000000             0.000000                 0.000000
# 75%                  0.000000             0.000000                 0.000000
# max                  1.000000             1.000000                 1.000000
#
#        property_type_Casa particular (Cuba)  property_type_Chalet  \
# count                           7662.000000           7662.000000
# mean                               0.000261              0.000653
# std                                0.016155              0.025539
# min                                0.000000              0.000000
# 25%                                0.000000              0.000000
# 50%                                0.000000              0.000000
# 75%                                0.000000              0.000000
# max                                1.000000              1.000000
#
#        property_type_Condominium  property_type_Cottage  \
# count                7662.000000            7662.000000
# mean                    0.014487               0.003132
# std                     0.119495               0.055883
# min                     0.000000               0.000000
# 25%                     0.000000               0.000000
# 50%                     0.000000               0.000000
# 75%                     0.000000               0.000000
# max                     1.000000               1.000000
#
#        property_type_Earth house  property_type_Farm stay  \
# count                7662.000000              7662.000000
# mean                    0.000392                 0.000392
# std                     0.019785                 0.019785
# min                     0.000000                 0.000000
# 25%                     0.000000                 0.000000
# 50%                     0.000000                 0.000000
# 75%                     0.000000                 0.000000
# max                     1.000000                 1.000000
#
#        property_type_Guest suite  property_type_Guesthouse  \
# count                7662.000000               7662.000000
# mean                    0.006004                  0.013835
# std                     0.077255                  0.116811
# min                     0.000000                  0.000000
# 25%                     0.000000                  0.000000
# 50%                     0.000000                  0.000000
# 75%                     0.000000                  0.000000
# max                     1.000000                  1.000000
#
#        property_type_Hostel  property_type_Hotel  property_type_House  \
# count           7662.000000          7662.000000          7662.000000
# mean               0.002871             0.000131             0.107544
# std                0.053511             0.011424             0.309823
# min                0.000000             0.000000             0.000000
# 25%                0.000000             0.000000             0.000000
# 50%                0.000000             0.000000             0.000000
# 75%                0.000000             0.000000             0.000000
# max                1.000000             1.000000             1.000000
#
#        property_type_Hut  property_type_In-law  property_type_Loft  \
# count        7662.000000           7662.000000         7662.000000
# mean            0.000522              0.000131            0.040459
# std             0.022844              0.011424            0.197047
# min             0.000000              0.000000            0.000000
# 25%             0.000000              0.000000            0.000000
# 50%             0.000000              0.000000            0.000000
# 75%             0.000000              0.000000            0.000000
# max             1.000000              1.000000            1.000000
#
#        property_type_Nature lodge  property_type_Other  \
# count                 7662.000000          7662.000000
# mean                     0.000131             0.000653
# std                      0.011424             0.025539
# min                      0.000000             0.000000
# 25%                      0.000000             0.000000
# 50%                      0.000000             0.000000
# 75%                      0.000000             0.000000
# max                      1.000000             1.000000
#
#        property_type_Serviced apartment  property_type_Tiny house  \
# count                       7662.000000               7662.000000
# mean                           0.025842                  0.003263
# std                            0.158674                  0.057032
# min                            0.000000                  0.000000
# 25%                            0.000000                  0.000000
# 50%                            0.000000                  0.000000
# 75%                            0.000000                  0.000000
# max                            1.000000                  1.000000
#
#        property_type_Townhouse  property_type_Villa  property_type_Windmill  \
# count              7662.000000          7662.000000             7662.000000
# mean                  0.016836             0.005873                0.000131
# std                   0.128666             0.076416                0.011424
# min                   0.000000             0.000000                0.000000
# 25%                   0.000000             0.000000                0.000000
# 50%                   0.000000             0.000000                0.000000
# 75%                   0.000000             0.000000                0.000000
# max                   1.000000             1.000000                1.000000
#
#        property_type_Yurt  time_in_operation  time_2_first_review  \
# count         7662.000000        7662.000000           7662.00000
# mean             0.000131        1193.487210            548.23362
# std              0.011424         768.940053            645.67783
# min              0.000000        -471.000000          -1292.00000
# 25%              0.000000         566.250000             36.25000
# 50%              0.000000        1106.500000            277.50000
# 75%              0.000000        1661.750000            866.00000
# max              1.000000        3407.000000           3384.00000
#
#         host_in_pt  price_per_guest
# count  7662.000000      7662.000000
# mean      0.730358        18.397676
# std       0.443803         9.264684
# min       0.000000         5.000000
# 25%       0.000000        12.000000
# 50%       1.000000        16.000000
# 75%       1.000000        22.500000
# max       1.000000        60.000000
#
# [8 rows x 224 columns]

# %%
lisbon.describe()
# Out:
#          Unnamed: 0            id       transit       host_id  \
# count  16329.000000  1.632900e+04  16329.000000  1.632900e+04
# mean   12143.707208  2.072244e+07      0.734031  8.192266e+07
# std     6915.713314  1.071779e+07      0.441861  8.268654e+07
# min        0.000000  6.499000e+03      0.000000  1.445500e+04
# 25%     6265.000000  1.304992e+07      0.000000  1.189208e+07
# 50%    12170.000000  2.136805e+07      1.000000  4.693613e+07
# 75%    18039.000000  2.930515e+07      1.000000  1.408932e+08
# max    24920.000000  4.015424e+07      1.000000  3.087456e+08
#
#        host_response_time  host_response_rate  host_is_superhost  \
# count        16329.000000        16329.000000       16329.000000
# mean             3.756936           97.009982           0.343805
# std              0.589818           10.834043           0.474992
# min              1.000000            0.000000           0.000000
# 25%              4.000000          100.000000           0.000000
# 50%              4.000000          100.000000           0.000000
# 75%              4.000000          100.000000           1.000000
# max              4.000000          100.000000           1.000000
#
#        host_listings_count  host_has_profile_pic  host_identity_verified  \
# count         16329.000000          16329.000000            16329.000000
# mean             21.081266              0.999388                0.319493
# std              64.081041              0.024740                0.466294
# min               0.000000              0.000000                0.000000
# 25%               1.000000              1.000000                0.000000
# 50%               4.000000              1.000000                0.000000
# 75%              13.000000              1.000000                1.000000
# max             505.000000              1.000000                1.000000
#
#            latitude     longitude  is_location_exact     room_type  \
# count  16329.000000  16329.000000       16329.000000  16329.000000
# mean      38.742648     -9.191297           0.610019      1.213914
# std        0.083326      0.102701           0.487761      0.479861
# min       38.675090     -9.483210           0.000000      1.000000
# 25%       38.710790     -9.173190           0.000000      1.000000
# 50%       38.716030     -9.145290           1.000000      1.000000
# 75%       38.730920     -9.133740           1.000000      1.000000
# max       39.296190     -8.867250           1.000000      4.000000
#
#        accommodates     bathrooms      bedrooms          beds         price  \
# count  16329.000000  16329.000000  16329.000000  16329.000000  16329.000000
# mean       4.202462      1.400208      1.695082      2.566906     83.093331
# std        2.299807      0.783708      1.371805      2.052996     65.511703
# min        1.000000      0.000000      0.000000      0.000000      9.000000
# 25%        2.000000      1.000000      1.000000      1.000000     49.000000
# 50%        4.000000      1.000000      1.000000      2.000000     67.000000
# 75%        5.000000      2.000000      2.000000      3.000000     98.000000
# max       26.000000     13.500000    100.000000    100.000000    900.000000
#
#        security_deposit  cleaning_fee  guests_included  extra_people  \
# count      16329.000000  16329.000000     16329.000000  16329.000000
# mean           0.905812     30.590483         2.245575      9.369894
# std            0.292099     24.015207         1.695912     10.114575
# min            0.000000      0.000000         1.000000      0.000000
# 25%            1.000000     15.000000         1.000000      0.000000
# 50%            1.000000     30.000000         2.000000     10.000000
# 75%            1.000000     40.000000         2.000000     15.000000
# max            1.000000    300.000000        26.000000    250.000000
#
#        minimum_nights  maximum_nights  has_availability  availability_365  \
# count    16329.000000    1.632900e+04           16329.0      16329.000000
# mean         2.547002    3.221641e+05               1.0        243.166575
# std          5.437466    2.427286e+07               0.0        120.694336
# min          1.000000    1.000000e+00               1.0          0.000000
# 25%          2.000000    9.000000e+01               1.0        153.000000
# 50%          2.000000    1.125000e+03               1.0        299.000000
# 75%          3.000000    1.125000e+03               1.0        344.000000
# max        300.000000    2.147484e+09               1.0        365.000000
#
#        number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# count       16329.000000           16329.000000          16329.000000
# mean           54.011085              19.571437             92.638618
# std            67.211570              19.489364              7.636679
# min             1.000000               0.000000             20.000000
# 25%             9.000000               4.000000             90.000000
# 50%            28.000000              13.000000             95.000000
# 75%            74.000000              30.000000             98.000000
# max           666.000000             336.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count            16329.000000               16329.000000
# mean                 9.585155                   9.455264
# std                  0.755263                   0.821068
# min                  2.000000                   2.000000
# 25%                  9.000000                   9.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count           16329.000000                 16329.000000
# mean                9.655582                     9.676220
# std                 0.734675                     0.717902
# min                 2.000000                     2.000000
# 25%                 9.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  instant_bookable  \
# count            16329.000000         16329.000000      16329.000000
# mean                 9.561333             9.213975          0.778982
# std                  0.661592             0.822588          0.414945
# min                  2.000000             2.000000          0.000000
# 25%                  9.000000             9.000000          1.000000
# 50%                 10.000000             9.000000          1.000000
# 75%                 10.000000            10.000000          1.000000
# max                 10.000000            10.000000          1.000000
#
#        is_business_travel_ready  cancellation_policy  \
# count                   16329.0         16329.000000
# mean                        0.0             2.418152
# std                         0.0             0.730741
# min                         0.0             1.000000
# 25%                         0.0             2.000000
# 50%                         0.0             3.000000
# 75%                         0.0             3.000000
# max                         0.0             5.000000
#
#        require_guest_profile_picture  require_guest_phone_verification  \
# count                   16329.000000                      16329.000000
# mean                        0.010962                          0.041889
# std                         0.104128                          0.200341
# min                         0.000000                          0.000000
# 25%                         0.000000                          0.000000
# 50%                         0.000000                          0.000000
# 75%                         0.000000                          0.000000
# max                         1.000000                          1.000000
#
#        calculated_host_listings_count  \
# count                    16329.000000
# mean                        16.918917
# std                         44.873122
# min                          1.000000
# 25%                          1.000000
# 50%                          4.000000
# 75%                         12.000000
# max                        315.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 16329.000000
# mean                                     14.948497
# std                                      44.816513
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       2.000000
# 75%                                       8.000000
# max                                     315.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  16329.000000
# mean                                       1.722579
# std                                        5.795845
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       66.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# count                                 16329.000000       16329.000000
# mean                                      0.069692           1.973488
# std                                       0.832223           1.639823
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.640000
# 50%                                       0.000000           1.550000
# 75%                                       0.000000           2.960000
# max                                      20.000000          17.580000
#
#        host_name_present  last_review_present  first_review_present  \
# count            16329.0              16329.0               16329.0
# mean                 1.0                  1.0                   1.0
# std                  0.0                  0.0                   0.0
# min                  1.0                  1.0                   1.0
# 25%                  1.0                  1.0                   1.0
# 50%                  1.0                  1.0                   1.0
# 75%                  1.0                  1.0                   1.0
# max                  1.0                  1.0                   1.0
#
#        host_since_present  reviews_p_month_present  amenities_count  \
# count             16329.0                  16329.0     16329.000000
# mean                  1.0                      1.0        27.276134
# std                   0.0                      0.0        11.745108
# min                   1.0                      1.0         1.000000
# 25%                   1.0                      1.0        18.000000
# 50%                   1.0                      1.0        26.000000
# 75%                   1.0                      1.0        34.000000
# max                   1.0                      1.0        87.000000
#
#        neighbourhood_group_cleansed_Amadora  ...  \
# count                          16329.000000  ...
# mean                               0.003736  ...
# std                                0.061008  ...
# min                                0.000000  ...
# 25%                                0.000000  ...
# 50%                                0.000000  ...
# 75%                                0.000000  ...
# max                                1.000000  ...
#
#        neighbourhood_cleansed_So Vicente  \
# count                       16329.000000
# mean                            0.071958
# std                             0.258426
# min                             0.000000
# 25%                             0.000000
# 50%                             0.000000
# 75%                             0.000000
# max                             1.000000
#
#        neighbourhood_cleansed_Sobral de Monte Agrao  \
# count                                  16329.000000
# mean                                       0.000184
# std                                        0.013554
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        neighbourhood_cleansed_Turcifal  neighbourhood_cleansed_Vale do Paraso  \
# count                     16329.000000                           16329.000000
# mean                          0.000306                               0.000061
# std                           0.017497                               0.007826
# min                           0.000000                               0.000000
# 25%                           0.000000                               0.000000
# 50%                           0.000000                               0.000000
# 75%                           0.000000                               0.000000
# max                           1.000000                               1.000000
#
#        neighbourhood_cleansed_Venda do Pinheiro e Santo Estvo das Gals  \
# count                                       16329.000000
# mean                                            0.000367
# std                                             0.019166
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        neighbourhood_cleansed_Venteira  neighbourhood_cleansed_Ventosa  \
# count                     16329.000000                    16329.000000
# mean                          0.000612                        0.000245
# std                           0.024740                        0.015650
# min                           0.000000                        0.000000
# 25%                           0.000000                        0.000000
# 50%                           0.000000                        0.000000
# 75%                           0.000000                        0.000000
# max                           1.000000                        1.000000
#
#        neighbourhood_cleansed_Vermelha  neighbourhood_cleansed_Vialonga  \
# count                     16329.000000                     16329.000000
# mean                          0.000061                         0.000061
# std                           0.007826                         0.007826
# min                           0.000000                         0.000000
# 25%                           0.000000                         0.000000
# 50%                           0.000000                         0.000000
# 75%                           0.000000                         0.000000
# max                           1.000000                         1.000000
#
#        neighbourhood_cleansed_Vila Franca de Xira  \
# count                                16329.000000
# mean                                     0.000796
# std                                      0.028205
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      1.000000
#
#        neighbourhood_cleansed_Vimeiro  neighbourhood_cleansed_guas Livres  \
# count                    16329.000000                        16329.000000
# mean                         0.000184                            0.001531
# std                          0.013554                            0.039099
# min                          0.000000                            0.000000
# 25%                          0.000000                            0.000000
# 50%                          0.000000                            0.000000
# 75%                          0.000000                            0.000000
# max                          1.000000                            1.000000
#
#        bed_type_Couch  bed_type_Futon  bed_type_Pull-out Sofa  \
# count    16329.000000    16329.000000            16329.000000
# mean         0.000306        0.000551                0.004593
# std          0.017497        0.023471                0.067618
# min          0.000000        0.000000                0.000000
# 25%          0.000000        0.000000                0.000000
# 50%          0.000000        0.000000                0.000000
# 75%          0.000000        0.000000                0.000000
# max          1.000000        1.000000                1.000000
#
#        bed_type_Real Bed  property_type_Apartment  \
# count       16329.000000             16329.000000
# mean            0.994366                 0.812113
# std             0.074852                 0.390634
# min             0.000000                 0.000000
# 25%             1.000000                 1.000000
# 50%             1.000000                 1.000000
# 75%             1.000000                 1.000000
# max             1.000000                 1.000000
#
#        property_type_Bed and breakfast  property_type_Boat  \
# count                     16329.000000        16329.000000
# mean                          0.005205            0.002878
# std                           0.071963            0.053574
# min                           0.000000            0.000000
# 25%                           0.000000            0.000000
# 50%                           0.000000            0.000000
# 75%                           0.000000            0.000000
# max                           1.000000            1.000000
#
#        property_type_Boutique hotel  property_type_Bungalow  \
# count                  16329.000000            16329.000000
# mean                       0.002021                0.000612
# std                        0.044911                0.024740
# min                        0.000000                0.000000
# 25%                        0.000000                0.000000
# 50%                        0.000000                0.000000
# 75%                        0.000000                0.000000
# max                        1.000000                1.000000
#
#        property_type_Cabin  property_type_Camper/RV  property_type_Campsite  \
# count         16329.000000             16329.000000            16329.000000
# mean              0.000245                 0.004654                0.000245
# std               0.015650                 0.068066                0.015650
# min               0.000000                 0.000000                0.000000
# 25%               0.000000                 0.000000                0.000000
# 50%               0.000000                 0.000000                0.000000
# 75%               0.000000                 0.000000                0.000000
# max               1.000000                 1.000000                1.000000
#
#        property_type_Casa particular (Cuba)  property_type_Castle  \
# count                          16329.000000          16329.000000
# mean                               0.000184              0.000367
# std                                0.013554              0.019166
# min                                0.000000              0.000000
# 25%                                0.000000              0.000000
# 50%                                0.000000              0.000000
# 75%                                0.000000              0.000000
# max                                1.000000              1.000000
#
#        property_type_Chalet  property_type_Condominium  property_type_Cottage  \
# count          16329.000000               16329.000000           16329.000000
# mean               0.000980                   0.024802               0.007410
# std                0.031288                   0.155528               0.085765
# min                0.000000                   0.000000               0.000000
# 25%                0.000000                   0.000000               0.000000
# 50%                0.000000                   0.000000               0.000000
# 75%                0.000000                   0.000000               0.000000
# max                1.000000                   1.000000               1.000000
#
#        property_type_Dome house  property_type_Earth house  \
# count              16329.000000               16329.000000
# mean                   0.000122                   0.000184
# std                    0.011067                   0.013554
# min                    0.000000                   0.000000
# 25%                    0.000000                   0.000000
# 50%                    0.000000                   0.000000
# 75%                    0.000000                   0.000000
# max                    1.000000                   1.000000
#
#        property_type_Farm stay  property_type_Guest suite  \
# count             16329.000000               16329.000000
# mean                  0.000551                   0.005144
# std                   0.023471                   0.071541
# min                   0.000000                   0.000000
# 25%                   0.000000                   0.000000
# 50%                   0.000000                   0.000000
# 75%                   0.000000                   0.000000
# max                   1.000000                   1.000000
#
#        property_type_Guesthouse  property_type_Hostel  property_type_Hotel  \
# count              16329.000000          16329.000000         16329.000000
# mean                   0.008757              0.004960             0.000367
# std                    0.093173              0.070258             0.019166
# min                    0.000000              0.000000             0.000000
# 25%                    0.000000              0.000000             0.000000
# 50%                    0.000000              0.000000             0.000000
# 75%                    0.000000              0.000000             0.000000
# max                    1.000000              1.000000             1.000000
#
#        property_type_House  property_type_Houseboat  property_type_Hut  \
# count         16329.000000             16329.000000       16329.000000
# mean              0.059220                 0.000122           0.000184
# std               0.236043                 0.011067           0.013554
# min               0.000000                 0.000000           0.000000
# 25%               0.000000                 0.000000           0.000000
# 50%               0.000000                 0.000000           0.000000
# 75%               0.000000                 0.000000           0.000000
# max               1.000000                 1.000000           1.000000
#
#        property_type_Lighthouse  property_type_Loft  property_type_Other  \
# count              16329.000000        16329.000000         16329.000000
# mean                   0.000061            0.013350             0.000429
# std                    0.007826            0.114774             0.020701
# min                    0.000000            0.000000             0.000000
# 25%                    0.000000            0.000000             0.000000
# 50%                    0.000000            0.000000             0.000000
# 75%                    0.000000            0.000000             0.000000
# max                    1.000000            1.000000             1.000000
#
#        property_type_Serviced apartment  property_type_Tent  \
# count                      16329.000000        16329.000000
# mean                           0.017515            0.000061
# std                            0.131184            0.007826
# min                            0.000000            0.000000
# 25%                            0.000000            0.000000
# 50%                            0.000000            0.000000
# 75%                            0.000000            0.000000
# max                            1.000000            1.000000
#
#        property_type_Tiny house  property_type_Townhouse  property_type_Villa  \
# count              16329.000000             16329.000000         16329.000000
# mean                   0.001898                 0.007778             0.016106
# std                    0.043531                 0.087850             0.125888
# min                    0.000000                 0.000000             0.000000
# 25%                    0.000000                 0.000000             0.000000
# 50%                    0.000000                 0.000000             0.000000
# 75%                    0.000000                 0.000000             0.000000
# max                    1.000000                 1.000000             1.000000
#
#        property_type_Windmill  property_type_Yurt  time_in_operation  \
# count            16329.000000        16329.000000       16329.000000
# mean                 0.000674            0.000061        1446.063139
# std                  0.025947            0.007826         823.039206
# min                  0.000000            0.000000        -372.000000
# 25%                  0.000000            0.000000         776.000000
# 50%                  0.000000            0.000000        1397.000000
# 75%                  0.000000            0.000000        2044.000000
# max                  1.000000            1.000000        3849.000000
#
#        time_2_first_review    host_in_pt  price_per_guest
# count         16329.000000  16329.000000     16329.000000
# mean            706.567457      0.792210        20.668935
# std             725.801438      0.405738        10.027576
# min           -2116.000000      0.000000         5.000000
# 25%              77.000000      1.000000        13.750000
# 50%             472.000000      1.000000        18.333333
# 75%            1157.000000      1.000000        25.000000
# max            3587.000000      1.000000        70.000000
#
# [8 rows x 225 columns]

# %%
#function to scale and normalize the dataframes features
def feature_scaling(df, type_scale):
    '''
    This function takes in either the azdias or the customers dataframe and applyes the selected feature scaler
    Args: customer or azdias dataframe and a string representing the type of scaling intended
    returns: scaled dataframe
    '''
    
    features_list = df.columns
    
    if type_scale == 'StandardScaler':
        df_scaled = StandardScaler().fit_transform(df)
        
    if type_scale == 'MinMaxScaler':
        df_scaled = MinMaxScaler().fit_transform(df)
    
    df_scaled = pd.DataFrame(df_scaled)
    df_scaled.columns = features_list
    
    return df_scaled

# %%
#pca model
def pca_model(df, n_components):
    '''
    This function defines a model that takes in a previously scaled dataframe and returns the result of 
    the transformation. The output is an onject created post data fitting
    '''
    pca = PCA(n_components)
    pca_df = pca.fit(df)
    
    return pca_df

# %%
import matplotlib.pyplot as plt
from pylab import *
#scree plots for PCA
def scree_plots(SS1,SS2, dataname1, dataname2):
    '''
    This function takes in the transformed data using PCA and plots it in scree plots
    '''
    subplot(2,1,1)

    plt.plot(np.cumsum(SS1.explained_variance_ratio_))
    plt.xlabel('Number of Components')
    plt.ylabel('Explained Variance Ratio')
    plt.title('Explained Variance Ratio vs Number of Components SS' + dataname1)
    plt.grid(b=True)

    subplot(2,1,2)
    plt.plot(np.cumsum(SS2.explained_variance_ratio_))
    plt.xlabel('Number of Components')
    plt.ylabel('Explained Variance Ratio')
    plt.title('Explained Variance Ratio vs Number of Components SS' + dataname2)
    plt.grid(b=True)

    plot = tight_layout()
    plot = plt.show()

# %%
porto_SS = feature_scaling(porto, 'StandardScaler')
lisbon_SS = feature_scaling(lisbon, 'StandardScaler')

n_components_porto = len(porto_SS.columns.values)
n_components_lisbon = len(lisbon_SS.columns.values)

porto_SS_pca = pca_model(porto_SS, n_components_porto)
lisbon_SS_pca = pca_model(lisbon_SS, n_components_lisbon)

scree_plots(porto_SS_pca, lisbon_SS_pca, ' Porto', ' Lisbon')

# %% [markdown]
# Using standard scaler with 150 principal components 90% of the original variance can be represented

# %%
X_porto = porto.drop('price', 1)
y_porto = porto['price']

X_lisbon = lisbon.drop('price', 1)
y_lisbon = lisbon['price']

# %%
# split our data
X_porto_train, X_porto_test, y_porto_train, y_porto_test = train_test_split(X_porto, y_porto, test_size=0.33)

X_lisbon_train, X_lisbon_test, y_lisbon_train, y_lisbon_test = train_test_split(X_lisbon, y_lisbon, test_size=0.33)

# %% [markdown]
# ### Linear Regression with no scaling, scalling, with pca and without pca

# %%
#no scaling and no dimensionality reduction
no_scale_no_pca = Pipeline([('linear', linear_model.LinearRegression())])
no_scale_no_pca.fit(X_porto_train, y_porto_train)
y_pred1_porto = no_scale_no_pca.predict(X_porto_test)
linear_reg_err1_porto = metrics.median_absolute_error(y_porto_test, y_pred1_porto)
linear_reg_r21_porto = metrics.r2_score(y_porto_test, y_pred1_porto)


#with scaling, no dimensionality reduction
scale_no_pca = Pipeline([('standardize', StandardScaler()), ('linear', linear_model.LinearRegression())])
scale_no_pca.fit(X_porto_train, y_porto_train)
y_pred2_porto = scale_no_pca.predict(X_porto_test)
linear_reg_err2_porto = metrics.median_absolute_error(y_porto_test, y_pred2_porto)
linear_reg_r22_porto = metrics.r2_score(y_porto_test, y_pred2_porto)

    
#scaling and dimensionality reduction
scale_pca = Pipeline([('standardize', StandardScaler()),
    ('pca', PCA(n_components = 150)), ('linear', linear_model.LinearRegression())])
scale_pca.fit(X_porto_train, y_porto_train)
y_pred3_porto = scale_pca.predict(X_porto_test)
linear_reg_err3_porto = metrics.median_absolute_error(y_porto_test, y_pred3_porto)
linear_reg_r23_porto = metrics.r2_score(y_porto_test, y_pred3_porto)


print ("Linear Regression's MAE without PCA or scaling in Porto: " + str(linear_reg_err1_porto))
print ("Linear Regression's MAE deviation with scaling in Porto: " + str(linear_reg_err2_porto))
print ("Linear Regression's MAE deviation with PCA and scaling in Porto: " + str(linear_reg_err3_porto))

print ("Linear Regression's r2 without PCA or scaling in Porto: " + str(linear_reg_r21_porto))
print ("Linear Regression's r2 deviation with scaling in Porto: " + str(linear_reg_r22_porto))
print ("Linear Regression's r2 deviation with PCA and scaling in Porto: " + str(linear_reg_r23_porto))
# Out:
# Linear Regression's MAE without PCA or scaling in Porto: 6.818277236456424
# Linear Regression's MAE deviation with scaling in Porto: 6.922833298680807
# Linear Regression's MAE deviation with PCA and scaling in Porto: 10.987920907709793
# Linear Regression's r2 without PCA or scaling in Porto: 0.8214705662143811
# Linear Regression's r2 deviation with scaling in Porto: -3.197183251164882e+25
# Linear Regression's r2 deviation with PCA and scaling in Porto: 0.7385374599622486

# %%
plt.scatter(y_porto_test, y_pred1_porto, c = 'orange')

# %%
#no scaling and no dimensionality regression
no_scale_no_pca = Pipeline([('linear', linear_model.LinearRegression())])
no_scale_no_pca.fit(X_lisbon_train, y_lisbon_train)
y_pred1_lisbon = no_scale_no_pca.predict(X_lisbon_test)
linear_reg_err1_lisbon = metrics.median_absolute_error(y_lisbon_test, y_pred1_lisbon)
linear_reg_r21_lisbon = metrics.r2_score(y_lisbon_test, y_pred1_lisbon)


#with scaling, no dimensionality regression
scale_no_pca = Pipeline([('standardize', StandardScaler()), ('linear', linear_model.LinearRegression())])
scale_no_pca.fit(X_lisbon_train, y_lisbon_train)
y_pred2_lisbon = scale_no_pca.predict(X_lisbon_test)
linear_reg_err2_lisbon = metrics.median_absolute_error(y_lisbon_test, y_pred2_lisbon)
linear_reg_r22_lisbon = metrics.r2_score(y_lisbon_test, y_pred2_lisbon)

    
#scaling and dimensionality reduction
scale_pca = Pipeline([('standardize', StandardScaler()),
    ('pca', PCA(n_components = 150)), ('linear', linear_model.LinearRegression())])
scale_pca.fit(X_lisbon_train, y_lisbon_train)
y_pred3_lisbon = scale_pca.predict(X_lisbon_test)
linear_reg_err3_lisbon = metrics.median_absolute_error(y_lisbon_test, y_pred3_lisbon)
linear_reg_r23_lisbon = metrics.r2_score(y_lisbon_test, y_pred3_lisbon)


print ("Linear Regression's MAE without PCA or scaling in Lisbon: " + str(linear_reg_err1_lisbon))
print ("Linear Regression's MAE deviation with scaling in Lisbon: " + str(linear_reg_err2_lisbon))
print ("Linear Regression's MAE deviation with PCA and scaling in Lisbon: " + str(linear_reg_err3_lisbon))
print ("Linear Regression's r2 without PCA or scaling in Lisbon: " + str(linear_reg_r21_lisbon))
print ("Linear Regression's r2 deviation with scaling in Lisbon: " + str(linear_reg_r22_lisbon))
print ("Linear Regression's r2 deviation with PCA and scaling in Lisbon: " + str(linear_reg_r23_lisbon))
# Out:
# Linear Regression's MAE without PCA or scaling in Lisbon: 9.446945062747773
# Linear Regression's MAE deviation with scaling in Lisbon: 9.502143872689576
# Linear Regression's MAE deviation with PCA and scaling in Lisbon: 14.804102515693742
# Linear Regression's r2 without PCA or scaling in Lisbon: 0.8409378128703342
# Linear Regression's r2 deviation with scaling in Lisbon: -5.2514025610255746e+23
# Linear Regression's r2 deviation with PCA and scaling in Lisbon: 0.6851652897656335

# %% [markdown]
# ## Xgboost Regressor no scaling

# %%
booster = xgb.XGBRegressor()

param_grid = {'n_estimators': [100, 200, 300],
              'learning_rate': [0.01, 0.05, 0.1], 
              'max_depth': [3, 4, 5, 6, 7],
              'colsample_bytree': [0.6, 0.7, 1],
              'gamma': [0.0, 0.1, 0.2]}

booster_grid_search = GridSearchCV(booster, param_grid, cv=3, n_jobs=-1)

# %%
# train the tuned random forest porto
booster_grid_search.fit(X_porto_train, y_porto_train)

print(booster_grid_search.best_params_)
# Out:
# [11:08:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# {'colsample_bytree': 1, 'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 300}

# %%
# train the tuned random forest lisbon
booster_grid_search.fit(X_lisbon_train, y_lisbon_train)

print(booster_grid_search.best_params_)
# Out:
# [12:57:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# {'colsample_bytree': 1, 'gamma': 0.0, 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 300}

# %%
#instantiating the models based on the hyperparameters found by grid search
booster_porto = xgb.XGBRegressor(colsample_bytree=1, gamma=0.1, learning_rate=0.1, 
                           max_depth=3, n_estimators=300, random_state=4)

booster_lisbon = xgb.XGBRegressor(colsample_bytree=1, gamma=0.0, learning_rate=0.1, 
                           max_depth=4, n_estimators=300, random_state=4)

# %%
#training
booster_porto.fit(X_porto_train, y_porto_train)

booster_lisbon.fit(X_lisbon_train, y_lisbon_train)
# Out:
# [12:58:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:58:19] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0.1,
#              importance_type='gain', learning_rate=0.05, max_delta_step=0,
#              max_depth=5, min_child_weight=1, missing=None, n_estimators=300,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=4,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
#prediction
y_pred_train_porto = booster_porto.predict(X_porto_train)
y_pred_test_porto = booster_porto.predict(X_porto_test)

y_pred_train_lisbon = booster_lisbon.predict(X_lisbon_train)
y_pred_test_lisbon = booster_lisbon.predict(X_lisbon_test)

# %%
#metrics to determine quality of model
RMSE_porto = np.sqrt(mean_squared_error(y_porto_test, y_pred_test_porto))
RMSE_lisbon = np.sqrt(mean_squared_error(y_lisbon_test, y_pred_test_lisbon))

MSE_porto = mean_squared_error(y_porto_test, y_pred_test_porto)
MSE_lisbon = mean_squared_error(y_lisbon_test, y_pred_test_lisbon)

r2_porto = r2_score(y_porto_test, y_pred_test_porto)
r2_lisbon = r2_score(y_lisbon_test, y_pred_test_lisbon)



print(f"RMSE_porto: {round(RMSE_porto, 4)}")
print(f"RMSE_lisbon: {round(RMSE_lisbon, 4)}")

print(f"MSE_porto: {round(MSE_porto, 4)}")
print(f"MSE_lisbon: {round(MSE_lisbon, 4)}")

print(f"r2_porto: {round(r2_porto, 4)}")
print(f"r2_lisbon: {round(r2_lisbon, 4)}")
# Out:
# RMSE_porto: 4.8675
# RMSE_lisbon: 4.0141
# MSE_porto: 23.6923
# MSE_lisbon: 16.1133
# r2_porto: 0.9888
# r2_lisbon: 0.9959

# %% [markdown]
# ## XGboost with scaling

# %%
X_porto_SS = porto_SS.drop('price', 1)
y_porto_SS = porto_SS['price']

X_lisbon_SS = lisbon_SS.drop('price', 1)
y_lisbon_SS = lisbon_SS['price']

# %%
# split our data
X_porto_train, X_porto_test, y_porto_train, y_porto_test = train_test_split(X_porto_SS, y_porto_SS, test_size=0.2)

X_lisbon_train, X_lisbon_test, y_lisbon_train, y_lisbon_test = train_test_split(X_lisbon_SS, y_lisbon_SS, test_size=0.2)

# %%
booster = xgb.XGBRegressor()

param_grid = {'n_estimators': [100, 200, 300],
              'learning_rate': [0.01, 0.05, 0.1], 
              'max_depth': [3, 4, 5, 6, 7],
              'colsample_bytree': [0.6, 0.7, 1],
              'gamma': [0.0, 0.1, 0.2]}

booster_grid_search = GridSearchCV(booster, param_grid, cv=3, n_jobs=-1)

# %%
# train the tuned random forest porto
booster_grid_search.fit(X_porto_train, y_porto_train)

print(booster_grid_search.best_params_)
# Out:
# [14:01:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# {'colsample_bytree': 1, 'gamma': 0.0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 300}

# %%
# train the tuned random forest lisbon
booster_grid_search.fit(X_lisbon_train, y_lisbon_train)

print(booster_grid_search.best_params_)
# Out:
# [16:12:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# {'colsample_bytree': 1, 'gamma': 0.0, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 300}

# %%
#instantiating the models based on the hyperparameters found by grid search
booster_porto = xgb.XGBRegressor(colsample_bytree = 1, gamma = 0.0, learning_rate = 0.1, 
                           max_depth= 3, n_estimators = 300, random_state = 4)

booster_lisbon = xgb.XGBRegressor(colsample_bytree = 1, gamma = 0.0, learning_rate = 0.05, 
                           max_depth = 4, n_estimators = 300, random_state = 4)

# %%
#training
booster_porto.fit(X_porto_train, y_porto_train)

booster_lisbon.fit(X_lisbon_train, y_lisbon_train)
# Out:
# [16:12:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:13:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0.0,
#              importance_type='gain', learning_rate=0.05, max_delta_step=0,
#              max_depth=4, min_child_weight=1, missing=None, n_estimators=300,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=4,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
#prediction
y_pred_train_porto = booster_porto.predict(X_porto_train)
y_pred_test_porto = booster_porto.predict(X_porto_test)

y_pred_train_lisbon = booster_lisbon.predict(X_lisbon_train)
y_pred_test_lisbon = booster_lisbon.predict(X_lisbon_test)

# %%
#metrics to determine quality of model
RMSE_porto = np.sqrt(mean_squared_error(y_porto_test, y_pred_test_porto))
RMSE_lisbon = np.sqrt(mean_squared_error(y_lisbon_test, y_pred_test_lisbon))

MSE_porto = mean_squared_error(y_porto_test, y_pred_test_porto)
MSE_lisbon = mean_squared_error(y_lisbon_test, y_pred_test_lisbon)

r2_porto = r2_score(y_porto_test, y_pred_test_porto)
r2_lisbon = r2_score(y_lisbon_test, y_pred_test_lisbon)



print(f"RMSE_porto: {round(RMSE_porto, 4)}")
print(f"RMSE_lisbon: {round(RMSE_lisbon, 4)}")

print(f"MSE_porto: {round(MSE_porto, 4)}")
print(f"MSE_lisbon: {round(MSE_lisbon, 4)}")

print(f"r2_porto: {round(r2_porto, 4)}")
print(f"r2_lisbon: {round(r2_lisbon, 4)}")
# Out:
# RMSE_porto: 0.0997
# RMSE_lisbon: 0.0381
# MSE_porto: 0.0099
# MSE_lisbon: 0.0015
# r2_porto: 0.9922
# r2_lisbon: 0.9985
